# %% [markdown]
# # Simple linear regression

# %% [markdown]
# ### importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
house = pd.read_csv("Salary_dataset.csv")

# %%
house.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
house.drop_duplicates()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
print(house.isnull().sum())
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
y = house["Salary"]
x = house[["YearsExperience"]]  
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
y.mean()
# Out:
# np.float64(76004.0)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=85563)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((22, 1), (8, 1), (22,), (8,))

# %%
y_train = y_train.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((22, 1), (8, 1), (22, 1), (8, 1))

# %%
x_train
# Out:
#     YearsExperience
# 22              8.0
# 1               1.4
# 6               3.1
# 4               2.3
# 20              6.9
# 12              4.1
# 8               3.3
# 23              8.3
# 3               2.1
# 14              4.6
# 19              6.1
# 25              9.1
# 13              4.2
# 9               3.8
# 10              4.0
# 5               3.0
# 16              5.2
# 17              5.4
# 27              9.7
# 24              8.8
# 0               1.2
# 18              6.0

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('original')
plt.ylabel('predicted')
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
print("Accuracy: ", r2_score(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred)**0.5)
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# Accuracy:  0.9821478772259982
# MSE:  4294.654012154755
# MAE:  3623.7806829955025
